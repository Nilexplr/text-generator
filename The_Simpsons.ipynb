# %% [markdown]
# # Generer un dialogue des Simpson à l'aide d'une IA

# %% [markdown]
# # Entrainer un réseaux de neuronnes
#
# L'entrainement d'un réseaux de neuronnes peut être representer par cette simple courbe. Le but de l'entrainement va être d'atteindre le minimum global en répétant les phases de training
#
# ![Example-of-Local-and-Global-Minima-on-an-Error-Surface.png](attachment:Example-of-Local-and-Global-Minima-on-an-Error-Surface.png)
#
#
# # Qu'est ce que le learning rate ?
#
# Le learning rate correspond à la taille des "pas" que vas effectué l'algorithme après un entrainement.       Il est généralement inférieur à 1.
#
# ![learning_rate.png](attachment:learning_rate.png)
#
#
# # Qu'est ce que le nombre d'epochs ?
#
#
# Le nombre d'epochs correspond au nombre de fois que l'algorithme vas repasser sur la base de données pour   affiner l'entrainement
#
#
# # Quel est le lien entre learning rate et nombre d'epochs ?
#
# ![learningrate_epoch.png](attachment:learningrate_epoch.png)

# %%
# Rentrez le learning rate et le nombre d'epoch de votre choix

learning_rate = 42

num_epochs = 42

# %% [markdown]
# # Définir la taille d'un reseaux de neuronnes
#
# Les réseaux de neuronnes RNN sont un type de réseaux de neuronnes qui permet d'analyser du text et d'en déduire les pourcentage d'apparition d'une lettre par rapport à une suite d'autres lettres.
# Nous verrons en détails les RNN au cours de l'année. Leurs tailles est généralement comprisent entre 200 / 250 / 400 / 800 / 1000

# %%
rnn_size = 42

# %% [markdown]
# # Paramètres d'apprentissage lié aux data
#
# Seq_length vas correspondre au nombres de lettres qui composera la séquence envoyé au reseau de neuronnes. Il est conseillé de prendre un size entre 10 et 20 charactères, cela permettra au reseau de reconnaitre des patterns.

# %%
seq_length = 42

# %% [markdown]
# # Entrainement
#
# Pour s'assurer que l'algorithme apprend bien pendant la phase d'entrainement, il faut que la valeur "Val_loss" soit le plus proche de 0

# %%
from RNeuralNet import Train

Train(512, num_epochs, learning_rate, seq_length, rnn_size, 150)

# %% [markdown]
# # Utilisation du réseaux de neuronnes

# %%
from CreateTxt import Generator
length_generator = 500

# First word have to be 'moe_szyslak' / 'homer_simpson' / 'barney_gumble'
first_word = "barney_gumble"

Generator(length_generator, first_word)
